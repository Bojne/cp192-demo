# %%
import librosa
#path of the audio file
audio_data = './diane-official-music-video.wav'
#This returns an audio time series as a numpy array with a default sampling rate(sr) of 22KHZ
x = librosa.load(audio_data, sr=None)

#We can change this behavior by resampling at sr=44.1KHz.
x = librosa.load(audio_data, sr=44000)

# %%
x[0]
# Out:
# array([-0.02353517, -0.01973284, -0.01554306, ..., -0.00288867,
#        -0.00841562,  0.        ], dtype=float32)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import librosa.display
sr = 44000

plt.figure(figsize=(14, 5))
#plotting the sampled signal
type(librosa.display.waveplot(x[0], sr=sr))
# Out:
# matplotlib.collections.PolyCollection

# %%
#x: numpy array
X = librosa.stft(x[0])
#converting into energy levels(dB)
Xdb = librosa.amplitude_to_db(abs(X))

plt.figure(figsize=(20, 5))
y = librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
plt.figure(figsize=(20, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/librosa/display.py:974: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)
# /opt/anaconda3/lib/python3.7/site-packages/librosa/display.py:974: MatplotlibDeprecationWarning: The 'linthreshy' parameter of __init__() has been renamed 'linthresh' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)
# /opt/anaconda3/lib/python3.7/site-packages/librosa/display.py:974: MatplotlibDeprecationWarning: The 'linscaley' parameter of __init__() has been renamed 'linscale' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   scaler(mode, **kwargs)

# %%
# import numpy as np
# sr = 22050 # sample rate
# T = 5.0    # seconds
# t = np.linspace(0, T, int(T*sr), endpoint=False) # time variable
# x = 0.5*np.sin(2*np.pi*220*t)# pure sine wave at 220 Hz

# #playing generated audio
# ipd.Audio(x, rate=sr) # load a NumPy array

# librosa.output.write_wav('generated.wav', x, sr) # writing wave file in .wav format

# #min = minimum value for each row of the vector signal
# #max = maximum value for each row of the vector signal
# def normalize(x, axis=0):
#     return sklearn.preprocessing.minmax_scale(x, axis=axis)

# #Plotting the Spectral Centroid along the waveform
# librosa.display.waveplot(x[0], sr=sr, alpha=0.4)
# plt.plot(t, normalize(spectral_centroids), color='r')

# %%
chromagram = librosa.feature.chroma_stft(x[0], sr=sr)
plt.figure(figsize=(15, 5))
librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma', cmap='coolwarm')
